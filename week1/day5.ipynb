# %% [markdown]
# # A full business solution
#
# ## Now we will take our project from Day 1 to the next level
#
# ### BUSINESS CHALLENGE:
#
# Create a product that builds a Brochure for a company to be used for prospective clients, investors and potential recruits.
#
# We will be provided a company name and their primary website.
#
# See the end of this notebook for examples of real-world business applications.
#
# And remember: I'm always available if you have problems or ideas! Please do reach out.

# %%
# imports
# If these fail, please check you're running from an 'activated' environment with (llms) in the command prompt

import os
import requests
import json
from typing import List
from dotenv import load_dotenv
from bs4 import BeautifulSoup
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# Initialize and constants

load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if api_key and api_key.startswith('sk-proj-') and len(api_key)>10:
    print("API key looks good so far")
else:
    print("There might be a problem with your API key? Please visit the troubleshooting notebook!")
    
MODEL = 'gpt-4o-mini'
openai = OpenAI()
# Out:
# API key looks good so far

# %%
# A class to represent a Webpage

# Some websites need you to use proper headers when fetching them:
headers = {
 "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
}

class Website:
    """
    A utility class to represent a Website that we have scraped, now with links
    """

    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=headers)
        self.body = response.content
        soup = BeautifulSoup(self.body, 'html.parser')
        self.title = soup.title.string if soup.title else "No title found"
        if soup.body:
            for irrelevant in soup.body(["script", "style", "img", "input"]):
                irrelevant.decompose()
            self.text = soup.body.get_text(separator="\n", strip=True)
        else:
            self.text = ""
        links = [link.get('href') for link in soup.find_all('a')]
        self.links = [link for link in links if link]

    def get_contents(self):
        return f"Webpage Title:\n{self.title}\nWebpage Contents:\n{self.text}\n\n"

# %%
ed = Website("https://edwarddonner.com")
ed.links
# Out:
# ['https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'https://edwarddonner.com/',
#  'https://news.ycombinator.com',
#  'https://nebula.io/?utm_source=ed&utm_medium=referral',
#  'https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html',
#  'https://patents.google.com/patent/US20210049536A1/',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/',
#  'https://edwarddonner.com/',
#  'https://edwarddonner.com/connect-four/',
#  'https://edwarddonner.com/outsmart/',
#  'https://edwarddonner.com/about-me-and-about-nebula/',
#  'https://edwarddonner.com/posts/',
#  'mailto:hello@mygroovydomain.com',
#  'https://www.linkedin.com/in/eddonner/',
#  'https://twitter.com/edwarddonner',
#  'https://www.facebook.com/edward.donner.52']

# %% [markdown]
# ## First step: Have GPT-4o-mini figure out which links are relevant
#
# ### Use a call to gpt-4o-mini to read the links on a webpage, and respond in structured JSON.
# It should decide which links are relevant, and replace relative links such as "/about" with "https://company.com/about".
# We will use "one shot prompting" in which we provide an example of how it should respond in the prompt.
#
# This is an excellent use case for an LLM, because it requires nuanced understanding. Imagine trying to code this without LLMs by parsing and analyzing the webpage - it would be very hard!
#
# Sidenote: there is a more advanced technique called "Structured Outputs" in which we require the model to respond according to a spec. We cover this technique in Week 8 during our autonomous Agentic AI project.

# %%
link_system_prompt = "You are provided with a list of links found on a webpage. \
You are able to decide which of the links would be most relevant to include in a brochure about the company, \
such as links to an About page, or a Company page, or Careers/Jobs pages.\n"
link_system_prompt += "You should respond in JSON as in this example:"
link_system_prompt += """
{
    "links": [
        {"type": "about page", "url": "https://full.url/goes/here/about"},
        {"type": "careers page", "url": "https://another.full.url/careers"}
    ]
}
"""

# %%
print(link_system_prompt)
# Out:
# You are provided with a list of links found on a webpage. You are able to decide which of the links would be most relevant to include in a brochure about the company, such as links to an About page, or a Company page, or Careers/Jobs pages.
# You should respond in JSON as in this example:
# {
#     "links": [
#         {"type": "about page", "url": "https://full.url/goes/here/about"},
#         {"type": "careers page", "url": "https://another.full.url/careers"}
#     ]
# }

# %%
def get_links_user_prompt(website):
    user_prompt = f"Here is the list of links on the website of {website.url} - "
    user_prompt += "please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. \
Do not include Terms of Service, Privacy, email links.\n"
    user_prompt += "Links (some might be relative links):\n"
    user_prompt += "\n".join(website.links)
    return user_prompt

# %%
print(get_links_user_prompt(ed))
# Out:
# Here is the list of links on the website of https://edwarddonner.com - please decide which of these are relevant web links for a brochure about the company, respond with the full https URL in JSON format. Do not include Terms of Service, Privacy, email links.
# Links (some might be relative links):
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# https://edwarddonner.com/
# https://news.ycombinator.com
# https://nebula.io/?utm_source=ed&utm_medium=referral
# https://www.prnewswire.com/news-releases/wynden-stark-group-acquires-nyc-venture-backed-tech-startup-untapt-301269512.html
# https://patents.google.com/patent/US20210049536A1/
# https://www.linkedin.com/in/eddonner/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/05/18/2025-ai-executive-briefing/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/04/21/the-complete-agentic-ai-engineering-course/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/2025/01/23/llm-workshop-hands-on-with-agents-resources/
# https://edwarddonner.com/
# https://edwarddonner.com/connect-four/
# https://edwarddonner.com/outsmart/
# https://edwarddonner.com/about-me-and-about-nebula/
# https://edwarddonner.com/posts/
# mailto:hello@mygroovydomain.com
# https://www.linkedin.com/in/eddonner/
# https://twitter.com/edwarddonner
# https://www.facebook.com/edward.donner.52

# %%
def get_links(url):
    website = Website(url)
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": link_system_prompt},
            {"role": "user", "content": get_links_user_prompt(website)}
      ],
        response_format={"type": "json_object"}
    )
    result = response.choices[0].message.content
    return json.loads(result)

# %%
# Anthropic has made their site harder to scrape, so I'm using HuggingFace..

huggingface = Website("https://huggingface.co")
huggingface.links
# Out:
# ['/',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/docs',
#  '/enterprise',
#  '/pricing',
#  '/login',
#  '/join',
#  '/spaces',
#  '/models',
#  '/Qwen/Qwen-Image-Edit',
#  '/google/gemma-3-270m',
#  '/tencent/Hunyuan-GameCraft-1.0',
#  '/deepseek-ai/DeepSeek-V3.1-Base',
#  '/openai/gpt-oss-20b',
#  '/models',
#  '/spaces/enzostvs/deepsite',
#  '/spaces/Qwen/Qwen-Image',
#  '/spaces/zerogpu-aoti/wan2-2-fp8da-aoti-faster',
#  '/spaces/AIDC-AI/Ovis2.5-9B',
#  '/spaces/Qwen/Qwen-Image-Edit',
#  '/spaces',
#  '/datasets/fka/awesome-chatgpt-prompts',
#  '/datasets/nvidia/Granary',
#  '/datasets/nvidia/Llama-Nemotron-VLM-Dataset-v1',
#  '/datasets/allenai/WildChat-4.8M',
#  '/datasets/miromind-ai/MiroVerse-v0.1',
#  '/datasets',
#  '/join',
#  '/pricing#endpoints',
#  '/pricing#spaces',
#  '/pricing',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/enterprise',
#  '/allenai',
#  '/facebook',
#  '/amazon',
#  '/google',
#  '/Intel',
#  '/microsoft',
#  '/grammarly',
#  '/Writer',
#  '/docs/transformers',
#  '/docs/diffusers',
#  '/docs/safetensors',
#  '/docs/huggingface_hub',
#  '/docs/tokenizers',
#  '/docs/trl',
#  '/docs/transformers.js',
#  '/docs/smolagents',
#  '/docs/peft',
#  '/docs/datasets',
#  '/docs/text-generation-inference',
#  '/docs/accelerate',
#  '/models',
#  '/datasets',
#  '/spaces',
#  '/changelog',
#  'https://endpoints.huggingface.co',
#  '/chat',
#  '/huggingface',
#  '/brand',
#  '/terms-of-service',
#  '/privacy',
#  'https://apply.workable.com/huggingface/',
#  'mailto:press@huggingface.co',
#  '/learn',
#  '/docs',
#  '/blog',
#  'https://discuss.huggingface.co',
#  'https://status.huggingface.co/',
#  'https://github.com/huggingface',
#  'https://twitter.com/huggingface',
#  'https://www.linkedin.com/company/huggingface/',
#  '/join/discord']

# %%
get_links("https://huggingface.co")
# Out:
# {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'},
#   {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'},
#   {'type': 'blog page', 'url': 'https://huggingface.co/blog'},
#   {'type': 'community page', 'url': 'https://discuss.huggingface.co'},
#   {'type': 'GitHub page', 'url': 'https://github.com/huggingface'},
#   {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'},
#   {'type': 'LinkedIn page',
#    'url': 'https://www.linkedin.com/company/huggingface/'}]}

# %% [markdown]
# ## Second step: make the brochure!
#
# Assemble all the details into another prompt to GPT4-o

# %%
def get_all_details(url):
    result = "Landing page:\n"
    result += Website(url).get_contents()
    links = get_links(url)
    print("Found links:", links)
    for link in links["links"]:
        result += f"\n\n{link['type']}\n"
        result += Website(link["url"]).get_contents()
    return result

# %%
print(get_all_details("https://huggingface.co"))
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# Landing page:
# Webpage Title:
# Hugging Face – The AI community building the future.
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# The AI community building the future.
# The platform where the machine learning community collaborates on models, datasets, and applications.
# Explore AI Apps
# or
# Browse 1M+ models
# Trending on
# this week
# Models
# Qwen/Qwen-Image-Edit
# Updated
# 1 day ago
# •
# 608
# google/gemma-3-270m
# Updated
# 6 days ago
# •
# 6.49k
# •
# 469
# tencent/Hunyuan-GameCraft-1.0
# Updated
# about 16 hours ago
# •
# 407
# deepseek-ai/DeepSeek-V3.1-Base
# Updated
# about 8 hours ago
# •
# 360
# openai/gpt-oss-20b
# Updated
# 6 days ago
# •
# 3.65M
# •
# 3.13k
# Browse 1M+ models
# Spaces
# Running
# 12k
# 12k
# DeepSite v2
# 🐳
# Generate any application with DeepSeek
# Running
# on
# Zero
# 666
# 666
# Qwen Image
# 🖼
# Generate images from text prompts
# Running
# on
# Zero
# MCP
# 230
# 230
# Wan2.2 14B Fast
# 🎥
# generate a video from an image with a text prompt
# Running
# on
# Zero
# 131
# 131
# Ovis2.5 9B
# 📊
# High-accuracy vision & reasoning for complex tasks
# Running
# on
# Zero
# 117
# 117
# Qwen Image Edit
# ✒
# Edit images based on user instructions
# Browse 400k+ applications
# Datasets
# fka/awesome-chatgpt-prompts
# Updated
# Jan 6
# •
# 32.1k
# •
# 8.76k
# nvidia/Granary
# Updated
# 5 days ago
# •
# 726
# •
# 83
# nvidia/Llama-Nemotron-VLM-Dataset-v1
# Updated
# about 7 hours ago
# •
# 1.44k
# •
# 94
# allenai/WildChat-4.8M
# Updated
# 8 days ago
# •
# 1.37k
# •
# 78
# miromind-ai/MiroVerse-v0.1
# Updated
# 6 days ago
# •
# 578
# •
# 56
# Browse 250k+ datasets
# The Home of Machine Learning
# Create, discover and collaborate on ML better.
# The collaboration platform
# Host and collaborate on unlimited public models, datasets and applications.
# Move faster
# With the HF Open source stack.
# Explore all modalities
# Text, image, video, audio or even 3D.
# Build your portfolio
# Share your work with the world and build your ML profile.
# Sign Up
# Accelerate your ML
# We provide paid Compute and Enterprise solutions.
# Compute
# Deploy on optimized
# Inference Endpoints
# or update your
# Spaces applications
# to a GPU in a few clicks.
# View pricing
# Starting at $0.60/hour for GPU
# Team & Enterprise
# Give your team the most advanced platform to build AI with enterprise-grade security, access controls and
# 			dedicated support.
# Getting started
# Starting at $20/user/month
# Single Sign-On
# Regions
# Priority Support
# Audit Logs
# Resource Groups
# Private Datasets Viewer
# More than 50,000 organizations are using Hugging Face
# Ai2
# Enterprise
# non-profit
# •
# 783 models
# •
# 3.87k followers
# AI at Meta
# Enterprise
# company
# •
# 2.21k models
# •
# 7.31k followers
# Amazon
# company
# •
# 20 models
# •
# 3.36k followers
# Google
# Enterprise
# company
# •
# 1.04k models
# •
# 25.2k followers
# Intel
# company
# •
# 242 models
# •
# 2.9k followers
# Microsoft
# company
# •
# 419 models
# •
# 14.2k followers
# Grammarly
# Team
# company
# •
# 11 models
# •
# 172 followers
# Writer
# Enterprise
# company
# •
# 21 models
# •
# 321 followers
# Our Open Source
# We are building the foundation of ML tooling with the community.
# Transformers
# 148,519
# State-of-the-art AI models for PyTorch
# Diffusers
# 30,366
# State-of-the-art Diffusion models in PyTorch
# Safetensors
# 3,404
# Safe way to store/distribute neural network weights
# Hub Python Library
# 2,852
# Python client to interact with the Hugging Face Hub
# Tokenizers
# 10,001
# Fast tokenizers optimized for research & production
# TRL
# 15,162
# Train transformers LMs with reinforcement learning
# Transformers.js
# 14,372
# State-of-the-art ML running directly in your browser
# smolagents
# 22,225
# Smol library to build great agents in Python
# PEFT
# 19,355
# Parameter-efficient finetuning for large language models
# Datasets
# 20,525
# Access & share datasets for any ML tasks
# Text Generation Inference
# 10,430
# Serve language models with TGI optimized toolkit
# Accelerate
# 9,050
# Train PyTorch models with multi-GPU, TPU, mixed precision
# System theme
# Website
# Models
# Datasets
# Spaces
# Changelog
# Inference Endpoints
# HuggingChat
# Company
# About
# Brand assets
# Terms of service
# Privacy
# Jobs
# Press
# Resources
# Learn
# Documentation
# Blog
# Forum
# Service Status
# Social
# GitHub
# Twitter
# LinkedIn
# Discord
#
#
#
# about page
# Webpage Title:
# huggingface (Hugging Face)
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Hugging Face
# Enterprise
# company
# Verified
# https://huggingface.co
# huggingface
# huggingface
# Activity Feed
# Follow
# 54,750
# AI & ML interests
# The AI community building the future.
# Recent Activity
# nielsr
# updated
# a Space
# about 5 hours ago
# huggingface/ai-deadlines
# sayakpaul
# updated
# a dataset
# about 6 hours ago
# huggingface/diffusers-metadata
# mishig
# updated
# a Space
# about 10 hours ago
# huggingface/inference-playground
# View all activity
# Articles
# TimeScope: How Long Can Your Video Large Multimodal Model Go?
# 28 days ago
# •
# 37
# Yay! Organizations can now publish blog Articles
# Jan 20
# •
# 48
# Team members
# 210
# +176
# +163
# +142
# +132
# +112
# Organization Card
# Community
# About org cards
# 👋 Hi!
# We are on a mission to democratize
# good
# machine learning, one commit at a time.
# If that sounds like something you should be doing, why don't you
# join us
# !
# For press enquiries, you can
# ✉️ contact our team here
# .
# Collections
# 1
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 111k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 11.4M
# •
# •
# 743
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 872k
# •
# 209
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 2.53M
# •
# •
# 810
# DistilBERT release
# Original DistilBERT model, checkpoints obtained from using teacher-student learning from the original BERT checkpoints.
# distilbert/distilbert-base-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 111k
# •
# •
# 51
# distilbert/distilbert-base-uncased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 11.4M
# •
# •
# 743
# distilbert/distilbert-base-multilingual-cased
# Fill-Mask
# •
# 0.1B
# •
# Updated
# May 6, 2024
# •
# 872k
# •
# 209
# distilbert/distilbert-base-uncased-finetuned-sst-2-english
# Text Classification
# •
# 0.1B
# •
# Updated
# Dec 19, 2023
# •
# 2.53M
# •
# •
# 810
# spaces
# 30
# Sort:
# 		Recently updated
# pinned
# Running
# 16
# Enterprise Hub
# 🔒
# Why you need it, how to get it
# huggingface
# Jun 27
# pinned
# Running
# on
# CPU Upgrade
# 15
# Hugging Face Fast
# 🏎
# Test Hugging Face bandwidth
# huggingface
# Jun 12
# pinned
# Running
# 99
# Number Tokenization Blog
# 📈
# Explore how tokenization affects arithmetic in LLMs
# huggingface
# Dec 14, 2024
# Running
# 456
# AI Deadlines
# ⚡
# Generate project deadlines
# huggingface
# about 5 hours ago
# Running
# on
# CPU Upgrade
# 199
# Inference Playground
# 🔋
# Set theme for Hugging Face Playground
# huggingface
# about 10 hours ago
# Running
# on
# CPU Upgrade
# 19
# Openapi
# 🦀
# Hub API Documentation
# huggingface
# Jun 18
# View 30
# 							Spaces
# models
# 16
# Sort:
# 		Recently updated
# huggingface/time-series-transformer-tourism-monthly
# Time Series Forecasting
# •
# 0.0B
# •
# Updated
# May 24
# •
# 2.52k
# •
# 22
# huggingface/timesfm-tourism-monthly
# 0.0B
# •
# Updated
# Mar 31
# •
# 10
# •
# 2
# huggingface/CodeBERTa-language-id
# Text Classification
# •
# Updated
# Mar 29, 2024
# •
# 991
# •
# •
# 63
# huggingface/falcon-40b-gptq
# Text Generation
# •
# 7B
# •
# Updated
# Jun 14, 2023
# •
# 51
# •
# 13
# huggingface/autoformer-tourism-monthly
# Updated
# May 24, 2023
# •
# 2.05k
# •
# 10
# huggingface/distilbert-base-uncased-finetuned-mnli
# Text Classification
# •
# 0.1B
# •
# Updated
# Mar 22, 2023
# •
# 396
# •
# 2
# huggingface/informer-tourism-monthly
# Updated
# Feb 24, 2023
# •
# 2.25k
# •
# 6
# huggingface/the-no-branch-repo
# Text-to-Image
# •
# Updated
# Feb 10, 2023
# •
# 20
# •
# 6
# huggingface/CodeBERTa-small-v1
# Fill-Mask
# •
# Updated
# Jun 27, 2022
# •
# 57.6k
# •
# •
# 84
# huggingface/test-model-repo
# Updated
# Nov 19, 2021
# •
# 2
# View 16
# 							models
# datasets
# 34
# Sort:
# 		Recently updated
# huggingface/diffusers-metadata
# Viewer
# •
# Updated
# about 6 hours ago
# •
# 72
# •
# 862
# •
# 8
# huggingface/documentation-images
# Viewer
# •
# Updated
# about 11 hours ago
# •
# 55
# •
# 2.44M
# •
# 78
# huggingface/transformers-metadata
# Viewer
# •
# Updated
# about 12 hours ago
# •
# 1.83k
# •
# 1.06k
# •
# 27
# huggingface/policy-docs
# Viewer
# •
# Updated
# Jul 19
# •
# 26
# •
# 2.91k
# •
# 13
# huggingface/badges
# Viewer
# •
# Updated
# Jul 17
# •
# 1
# •
# 776k
# •
# 46
# huggingface/cats-image
# Viewer
# •
# Updated
# Jun 20
# •
# 1
# •
# 11.6k
# •
# 2
# huggingface/label-files
# Updated
# Jun 12
# •
# 2k
# •
# 19
# huggingface/electricity-production
# Viewer
# •
# Updated
# May 22
# •
# 397
# •
# 57
# •
# 1
# huggingface/gemini-results-new-cs-papers-2025-02-11-100-230-updated
# Viewer
# •
# Updated
# Feb 17
# •
# 130
# •
# 61
# huggingface/wiki_dpr
# Updated
# Feb 5
# •
# 252
# View 34
# 							datasets
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# careers page
# Webpage Title:
# Hugging Face - Current Openings
# Webpage Contents:
#
#
#
#
# blog
# Webpage Title:
# Hugging Face – Blog
# Webpage Contents:
# Hugging Face
# Models
# Datasets
# Spaces
# Community
# Docs
# Enterprise
# Pricing
# Log In
# Sign Up
# Blog, Articles, and discussions
# New Article
# Everything
# community
# guide
# open source collab
# partnerships
# research
# NLP
# Audio
# CV
# RL
# ethics
# Diffusion
# Game Development
# RLHF
# Leaderboard
# Case Studies
# LeRobot
# Inference Providers
# Generate Images with Claude and Hugging Face
# By
# evalstate
# August 19, 2025
# •
# 2
# Community Articles
# view all
# NVIDIA Releases 3 Million Sample Dataset for OCR, Visual Question Answering, and Captioning Tasks
# By
# nvidia
# and 4 others
# •
# 8 days ago
# •
# 56
# How To Build a News Agent with GPT-OSS, Hugging Face Inference & Gradio
# By
# fdaudens
# •
# 5 days ago
# •
# 17
# Supercharge Edge AI With High‑Accuracy Reasoning Using NVIDIA Nemotron Nano  2 9B
# By
# nvidia
# and 9 others
# •
# 1 day ago
# •
# 14
# ChatML vs Harmony: Understanding the new Format from OpenAI 🔍
# By
# kuotient
# •
# 10 days ago
# •
# 23
# Announcing the Synthetic Online Conversations Dataset (SOC)
# By
# marcodsn
# •
# 7 days ago
# •
# 11
# What’s MXFP4? The 4-Bit Secret Powering OpenAI’s GPT‑OSS Models on Modest Hardware
# By
# RakshitAralimatti
# •
# 11 days ago
# •
# 12
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 156
# RynnVLA-001: Using Human Demonstrations to Improve Robot Manipulation
# By
# Alibaba-DAMO-Academy
# and 9 others
# •
# 9 days ago
# •
# 25
# Kimina-Prover-RL
# By
# AI-MO
# and 18 others
# •
# 5 days ago
# •
# 8
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 654
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 208
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 115
# Post-Training Isaac GR00T N1.5 for LeRobot SO-101 Arm
# By
# nvidia
# and 5 others
# •
# Jun 11
# •
# 80
# Building Enterprise-Ready Text Classifiers in Minutes with Adaptive Learning
# By
# codelion
# •
# 11 days ago
# •
# 12
# Magpie Speech — Applying an LLM Data Synthesis Method to an LLM-Based TTS Model to Synthesize a Speech Dataset
# By
# Aratako
# •
# 6 days ago
# •
# 5
# RynnEC: Bringing MLLMs into Embodied World
# By
# Alibaba-DAMO-Academy
# and 6 others
# •
# 5 days ago
# •
# 5
# Introducing Pivotal Token Search (PTS): Targeting Critical Decision Points in LLM Training
# By
# codelion
# •
# May 17
# •
# 9
# How to Run a Hugging Face Model in JAX (Part 1)
# By
# qihqi
# •
# about 1 month ago
# •
# 21
# AWorld Multi-Agent System Hits #1 on GAIA Leaderboard
# By
# chengle
# •
# 12 days ago
# •
# 25
# The GPT-OSS models are here… and they’re energy-efficient!
# By
# sasha
# •
# 12 days ago
# •
# 19
# From Zero to GPU: A Guide to Building and Scaling Production-Ready CUDA Kernels
# By
# drbh
# August 18, 2025
# •
# 18
# MCP for Research: How to Connect AI to Research Tools
# By
# dylanebert
# August 18, 2025
# •
# 15
# TextQuests: How Good are LLMs at Text-Based Video Games?
# By
# justinphan3110
# August 12, 2025
# guest
# •
# 24
# Introducing AI Sheets: a tool to work with datasets using open AI models!
# By
# dvilasuero
# August 8, 2025
# •
# 63
# Accelerate ND-Parallel: A Guide to Efficient Multi-GPU Training
# By
# siro1
# August 8, 2025
# •
# 50
# 🇵🇭 FilBench - Can LLMs Understand and Generate Filipino?
# By
# ljvmiranda921
# August 12, 2025
# •
# 11
# Vision Language Model Alignment in TRL ⚡️
# By
# sergiopaniego
# August 7, 2025
# •
# 69
# Welcome GPT OSS, the new open-source model family from OpenAI!
# By
# reach-vb
# August 5, 2025
# •
# 465
# Build an AI Shopping Assistant with Gradio MCP Servers
# By
# freddyaboulton
# July 31, 2025
# •
# 49
# Introducing Trackio: A Lightweight Experiment Tracking Library from Hugging Face
# By
# abidlabs
# July 29, 2025
# •
# 155
# Say hello to `hf`: a faster, friendlier Hugging Face CLI ✨
# By
# Wauplin
# July 25, 2025
# •
# 76
# Parquet Content-Defined Chunking
# By
# kszucs
# July 25, 2025
# •
# 60
# TimeScope: How Long Can Your Video Large Multimodal Model Go?
# By
# orrzohar
# July 23, 2025
# •
# 37
# Fast LoRA inference for Flux with Diffusers and PEFT
# By
# sayakpaul
# July 23, 2025
# •
# 43
# Previous
# 1
# 2
# 3
# ...
# 45
# Next
# Community Articles
# Sort:
# 		Trending
# NVIDIA Releases 3 Million Sample Dataset for OCR, Visual Question Answering, and Captioning Tasks
# By
# nvidia
# and 4 others
# •
# 8 days ago
# •
# 56
# How To Build a News Agent with GPT-OSS, Hugging Face Inference & Gradio
# By
# fdaudens
# •
# 5 days ago
# •
# 17
# Supercharge Edge AI With High‑Accuracy Reasoning Using NVIDIA Nemotron Nano  2 9B
# By
# nvidia
# and 9 others
# •
# 1 day ago
# •
# 14
# ChatML vs Harmony: Understanding the new Format from OpenAI 🔍
# By
# kuotient
# •
# 10 days ago
# •
# 23
# Announcing the Synthetic Online Conversations Dataset (SOC)
# By
# marcodsn
# •
# 7 days ago
# •
# 11
# What’s MXFP4? The 4-Bit Secret Powering OpenAI’s GPT‑OSS Models on Modest Hardware
# By
# RakshitAralimatti
# •
# 11 days ago
# •
# 12
# Code a simple RAG from scratch
# By
# ngxson
# •
# Oct 29, 2024
# •
# 156
# RynnVLA-001: Using Human Demonstrations to Improve Robot Manipulation
# By
# Alibaba-DAMO-Academy
# and 9 others
# •
# 9 days ago
# •
# 25
# Kimina-Prover-RL
# By
# AI-MO
# and 18 others
# •
# 5 days ago
# •
# 8
# Uncensor any LLM with abliteration
# By
# mlabonne
# •
# Jun 13, 2024
# •
# 654
# DeepSeek-R1 Dissection: Understanding PPO & GRPO Without Any Prior Reinforcement Learning Knowledge
# By
# NormalUhr
# •
# Feb 7
# •
# 208
# KV Caching Explained: Optimizing Transformer Inference Efficiency
# By
# not-lain
# •
# Jan 30
# •
# 115
# Post-Training Isaac GR00T N1.5 for LeRobot SO-101 Arm
# By
# nvidia
# and 5 others
# •
# Jun 11
# •
# 80
# Building Enterprise-Ready Text Classifiers in Minutes with Adaptive Learning
# By
# codelion
# •
# 11 days ago
# •
# 12
# Magpie Speech — Applying an LLM Data Synthesis Method to an LLM-Based TTS Model to Synthesize a Speech Dataset
# By
# Aratako
# •
# 6 days ago
# •
# 5
# RynnEC: Bringing MLLMs into Embodied World
# By
# Alibaba-DAMO-Academy
# and 6 others
# •
# 5 days ago
# •
# 5
# Introducing Pivotal Token Search (PTS): Targeting Critical Decision Points in LLM Training
# By
# codelion
# •
# May 17
# •
# 9
# How to Run a Hugging Face Model in JAX (Part 1)
# By
# qihqi
# •
# about 1 month ago
# •
# 21
# AWorld Multi-Agent System Hits #1 on GAIA Leaderboard
# By
# chengle
# •
# 12 days ago
# •
# 25
# The GPT-OSS models are here… and they’re energy-efficient!
# By
# sasha
# •
# 12 days ago
# •
# 19
# View all
# System theme
# Company
# TOS
# Privacy
# About
# Jobs
# Website
# Models
# Datasets
# Spaces
# Pricing
# Docs
#
#
#
# company page
# Webpage Title:
# Hugging Face | LinkedIn
# Webpage Contents:
# Skip to main content
# LinkedIn
# Top Content
# People
# Learning
# Jobs
# Games
# Get the app
# Join now
# Sign in
# Hugging Face
# Software Development
# The AI community building the future.
# See jobs
# Follow
# View all 604 employees
# Report this company
# About us
# The AI community building the future.
# Website
# https://huggingface.co
# External link for Hugging Face
# Industry
# Software Development
# Company size
# 51-200 employees
# Type
# Privately Held
# Founded
# 2016
# Specialties
# machine learning, natural language processing, and deep learning
# Products
# Hugging Face
# Hugging Face
# Natural Language Processing (NLP) Software
# We’re on a journey to solve and democratize artificial intelligence through natural language.
# Locations
# Primary
# Get directions
# Paris, FR
# Get directions
# Employees at Hugging Face
# Ludovic Huraux
# Rajat Arya
# Tech Lead & Software Engineer @ HF | prev: co-founder XetHub, Apple, Turi, AWS, Microsoft
# Jeff Boudier
# Product + Growth at Hugging Face
# Terrence Rohan
# Seed Investor
# See all employees
# Updates
# Hugging Face
# reposted this
# Leandro von Werra
# Head of Research at Hugging Face
# 6h
# Report this post
# Excited to release: Jupyter Agent 2
#
# The agent can load data, execute code, plot results inside Jupyter faster than you can scroll!
#
# 🤖 Powered by Qwen3-Coder
# ⚡️ Running on Cerebras
# ⚙️ Executed in E2B
# ↕️ Upload your files
#
# All videos are in *real time*!
# https://lnkd.in/en3bQMyc
# …more
# 442
# 19 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Sayak Paul
# ML @ Hugging Face 🤗
# 17h
# Report this post
# New Diffusers release is out.
#
# Really great to see the state of things in image edits, video fidelity being pushed further and further, thanks to the community!
#
# This release also features new fine-tuning scripts for Qwen-Image and Flux Kontext (with support for image inputs). So, get busy making these models your own 🤗
#
# We also improved the loading speed of Diffusers pipelines and models. This will become particularly evident when operating with large models like Wan, Qwen, etc.
#
# As always, don't forget to check out the release notes for the full disclosure. I will leave the link in the comments.
# 177
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Yoni Gozlan
# ML Engineer @Hugging Face 🤗
# 1d
# Report this post
# 🚀 Better late than never, SAM2 is now available in
# Hugging Face
# 🤗 Transformers!
#
# introduced by
# Meta
# FAIR, Segment Anything Model 2 (SAM2) is the natural evolution of the first SAM: extending promptable segmentation from static images into the video domain. With its streaming memory architecture, SAM2 can track and refine object masks across long videos in real time, making it one of the most powerful models for interactive and automatic video segmentation.
#
# The model builds a memory bank of past frames and prompts, encoding both spatial features and compact “object pointer” tokens that summarize the target. Each new frame is then processed in relation to this memory through attention, letting SAM2 recall what the object looked like and where it was last observed. Combined with an explicit occlusion prediction head, this design allows SAM2 to keep track of objects robustly and to recover them with minimal user input after partial or full occlusion.
#
# Many thanks to the team at Meta FAIR for developing and releasing such a foundational model for vision. I am happy to have worked on bringing SAM2 into Transformers together with
# Daniel Choi
# , making it easier than ever for the open-source community to use.
#
# 👉 Try SAM2 video tracking directly in this Hugging Face Space (the demo video below was made with it!):
# https://lnkd.in/e-UR8t_N
# * 🤗 SAM2.1 Large checkpoint:
# https://lnkd.in/eEQ_YyVT
# * 🤗 Transformers docs (SAM2):
# https://lnkd.in/eZ2gAUfh
# * 🤗 Transformers docs (SAM2 Video):
# https://lnkd.in/e3vuJxjM
# …more
# 714
# 15 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Vaibhav Srivastav
# whatever needs doing @ Hugging Face
# 2d
# Report this post
# NVIDIA ON A ROLL! Canary 1B and Parakeet TDT (0.6B) SoTA ASR models - Multilingual, Open Source 🔥
#
# - 1B and 600M parameters
# - 25 languages
# - automatic language detection and translation
# - word and sentence timestamps
# - transcribe up to 3 hours of audio in one go
# - trained on 1 Million hours of data
# - SoTA on Open ASR Leaderboard
#
# - CC-BY licensed 💥
#
# Available on Hugging Face, go check them out today!
# 440
# 36 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Daniel Vila Suero
# Building data tools @ Hugging Face 🤗
# 3d
# Report this post
# You can now use
# Hugging Face
# to generate and transform data at scale, no GPU required
#
#
# Thanks to HF Jobs, AI Sheets and vLLM!
#
#
# Here's the recipe:
#
# 1. go to
# https://lnkd.in/gdKeV-zW
# and import a dataset from the hub
#
# 2. add the columns you want (e.g., classifying text, generating responses to prompts, etc)
#
# 3. push the dataset to the hub
#
# 4. run this job script
# https://lnkd.in/diYnnY8J
# (see how to run it in the first comment)
# GitHub - huggingface/aisheets: Build, enrich, and transform datasets using AI models with no code
# github.com
# 232
# 5 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Vaibhav Srivastav
# whatever needs doing @ Hugging Face
# 6d
# Report this post
# OpenAI gpt-oss 120B orchestrates a full video using Hugging Face space! 🤯
#
# All of it, in one SINGLE prompt:
# create an image of a Labrador and use it to generate a simple video of it
#
# Full guide and steps here:
# https://lnkd.in/g8bhzR_e
# 🛠️ Tools used:
# 1. Flux.1 Krea Dev by
# Black Forest Labs
# 2. LTX Fast by
# Lightricks
# That's it, gpt-oss 120B is one of the BEST open source models I've used for tool calling so far! Kudos
# OpenAI
# 🤗
# …more
# 637
# 31 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Merve Noyan
# open-sourceress at 🤗
# 6d
# Report this post
# new TRL comes packed for vision language models 🔥
# we shipped support for
# > native supervised fine-tuning for VLMs
# > multimodal GRPO
# > MPO 🫡
#
# read all about it in our blog 🤗 in comments
# 296
# 4 Comments
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Brigitte Tousignant
# Comms 🤗
# 6d
# Report this post
# HAPPENING TODAY: Join
# Clem Delangue 🤗
# for an AMA on Discord!
# ⏰ 8am PST / 11am EST / 16h CET
#
# Join here:
# https://lnkd.in/dSqVsJqz
# Brigitte Tousignant
# Comms 🤗
# 1w
# It's been a wild summer full of epic open-source releases. 🚀 🚀🚀 Join
# Hugging Face
# CEO
# Clem Delangue 🤗
# for an AMA on the HF Discord this Wednesday, August 13, at 11 am EDT.
#
# Discord link:
# https://lnkd.in/dSqVsJqz
# See you there! 🤗
# 3
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Gradio
# 68,789 followers
# 1w
# Report this post
# Collaborators pick Gradio’s MCP integration for the best of both worlds:
# 🔹 Full MCP capabilities
# 🔹 A ready-to-go UI
#
# And we’re shipping continuous improvements + docs to keep the momentum going. Let's Go!
# 76
# 1 Comment
# Like
# Comment
# Share
# Hugging Face
# reposted this
# Romain Huet
# Head of Developer Experience at OpenAI. Previously, Product Lead at Stripe. Angel Investor & Advisor.
# 1w
# Report this post
# Over 5M downloads in under a week for our
# OpenAI
# open models, 400+ fine-tunes on
# Hugging Face
# . OpenAI gpt-oss-120b was the fastest model to gain popularity on the hub this year compared to other models. Love to see the community’s energy with these open models! 🤗
#
# Great to partner with
# Clem
# ,
# Thomas
# ,
# Julien
# ,
# Vaibhav
# ,
# Lysandre
# ,
# Lucain
# ,
# Pierric
# ,
# Lewis
# ,
# Quentin
# ,
# Irene
# , and many others from the
# Hugging Face
# team.
# 311
# 13 Comments
# Like
# Comment
# Share
# Join now to see what you are missing
# Find people you know at Hugging Face
# Browse recommended jobs for you
# View all updates, news, and articles
# Join now
# Similar pages
# Anthropic
# Research Services
# Perplexity
# Software Development
# San Francisco, California
# Mistral AI
# Technology, Information and Internet
# Paris, France
# OpenAI
# Research Services
# San Francisco, CA
# LangChain
# Technology, Information and Internet
# Generative AI
# Technology, Information and Internet
# Google DeepMind
# Research Services
# London, London
# DeepLearning.AI
# Software Development
# Palo Alto, California
# Cohere
# Software Development
# Toronto, Ontario
# LlamaIndex
# Technology, Information and Internet
# San Francisco, California
# Show more similar pages
# Show fewer similar pages
# Browse jobs
# Engineer jobs
# 555,845 open jobs
# Machine Learning Engineer jobs
# 148,937 open jobs
# Scientist jobs
# 48,969 open jobs
# Software Engineer jobs
# 300,699 open jobs
# Analyst jobs
# 694,057 open jobs
# Intern jobs
# 71,196 open jobs
# Developer jobs
# 258,935 open jobs
# Manager jobs
# 1,880,925 open jobs
# Product Manager jobs
# 199,941 open jobs
# Director jobs
# 1,220,357 open jobs
# Python Developer jobs
# 46,642 open jobs
# Data Scientist jobs
# 264,158 open jobs
# Data Analyst jobs
# 329,009 open jobs
# Senior Software Engineer jobs
# 78,145 open jobs
# Project Manager jobs
# 253,048 open jobs
# Researcher jobs
# 195,654 open jobs
# Associate jobs
# 1,091,945 open jobs
# Data Engineer jobs
# 192,126 open jobs
# Vice President jobs
# 235,270 open jobs
# Specialist jobs
# 768,666 open jobs
# Show more jobs like this
# Show fewer jobs like this
# Funding
# Hugging Face
# 8 total rounds
# Last Round
# Series unknown
# Sep 1, 2024
# External Crunchbase Link for last round of funding
# See more info on
# crunchbase
# More searches
# More searches
# Engineer jobs
# Scientist jobs
# Machine Learning Engineer jobs
# Software Engineer jobs
# Intern jobs
# Developer jobs
# Analyst jobs
# Manager jobs
# Senior Software Engineer jobs
# Data Scientist jobs
# Researcher jobs
# Product Manager jobs
# Director jobs
# Associate jobs
# Intelligence Specialist jobs
# Data Analyst jobs
# Data Science Specialist jobs
# Python Developer jobs
# Quantitative Analyst jobs
# Project Manager jobs
# Account Executive jobs
# Specialist jobs
# Data Engineer jobs
# Designer jobs
# Quantitative Researcher jobs
# Consultant jobs
# Solutions Architect jobs
# Vice President jobs
# User Experience Designer jobs
# Head jobs
# Full Stack Engineer jobs
# Engineering Manager jobs
# Software Engineer Intern jobs
# Junior Software Engineer jobs
# Software Intern jobs
# Product Designer jobs
# Solutions Engineer jobs
# Staff Software Engineer jobs
# Program Manager jobs
# Senior Scientist jobs
# Writer jobs
# Research Intern jobs
# Senior Product Manager jobs
# Summer Intern jobs
# Account Manager jobs
# Recruiter jobs
# Lead jobs
# Research Engineer jobs
# Computer Science Intern jobs
# Platform Engineer jobs
# Junior Developer jobs
# Android Developer jobs
# User Experience Researcher jobs
# Java Software Engineer jobs
# Site Reliability Engineer jobs
# Graduate jobs
# Software Engineering Manager jobs
# Representative jobs
# Business Development Specialist jobs
# Computer Engineer jobs
# LinkedIn
# © 2025
# About
# Accessibility
# User Agreement
# Privacy Policy
# Cookie Policy
# Copyright Policy
# Brand Policy
# Guest Controls
# Community Guidelines
# العربية (Arabic)
# বাংলা (Bangla)
# Čeština (Czech)
# Dansk (Danish)
# Deutsch (German)
# Ελληνικά (Greek)
# English (English)
# Español (Spanish)
# فارسی (Persian)
# Suomi (Finnish)
# Français (French)
# हिंदी (Hindi)
# Magyar (Hungarian)
# Bahasa Indonesia (Indonesian)
# Italiano (Italian)
# עברית (Hebrew)
# 日本語 (Japanese)
# 한국어 (Korean)
# मराठी (Marathi)
# Bahasa Malaysia (Malay)
# Nederlands (Dutch)
# Norsk (Norwegian)
# ਪੰਜਾਬੀ (Punjabi)
# Polski (Polish)
# Português (Portuguese)
# Română (Romanian)
# Русский (Russian)
# Svenska (Swedish)
# తెలుగు (Telugu)
# ภาษาไทย (Thai)
# Tagalog (Tagalog)
# Türkçe (Turkish)
# Українська (Ukrainian)
# Tiếng Việt (Vietnamese)
# 简体中文 (Chinese (Simplified))
# 正體中文 (Chinese (Traditional))
# Language
# Agree & Join LinkedIn
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# Sign in to see who you already know at Hugging Face
# Sign in
# Welcome back
# Email or phone
# Password
# Show
# Forgot password?
# Sign in
# or
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# New to LinkedIn?
# Join now
# or
# New to LinkedIn?
# Join now
# By clicking Continue to join or sign in, you agree to LinkedIn’s
# User Agreement
# ,
# Privacy Policy
# , and
# Cookie Policy
# .
# LinkedIn
# LinkedIn is better on the app
# Don’t have the app? Get it in the Microsoft Store.
# Open the app

# %%
system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
and creates a short brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
Include details of company culture, customers and careers/jobs if you have the information."

# Or uncomment the lines below for a more humorous brochure - this demonstrates how easy it is to incorporate 'tone':

# system_prompt = "You are an assistant that analyzes the contents of several relevant pages from a company website \
# and creates a short humorous, entertaining, jokey brochure about the company for prospective customers, investors and recruits. Respond in markdown.\
# Include details of company culture, customers and careers/jobs if you have the information."

# %%
def get_brochure_user_prompt(company_name, url):
    user_prompt = f"You are looking at a company called: {company_name}\n"
    user_prompt += f"Here are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\n"
    user_prompt += get_all_details(url)
    user_prompt = user_prompt[:5_000] # Truncate if more than 5,000 characters
    return user_prompt

# %%
get_brochure_user_prompt("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/about'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'community forum', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}]}
# "You are looking at a company called: HuggingFace\nHere are the contents of its landing page and other relevant pages; use this information to build a short brochure of the company in markdown.\nLanding page:\nWebpage Title:\nHugging Face – The AI community building the future.\nWebpage Contents:\nHugging Face\nModels\nDatasets\nSpaces\nCommunity\nDocs\nEnterprise\nPricing\nLog In\nSign Up\nThe AI community building the future.\nThe platform where the machine learning community collaborates on models, datasets, and applications.\nExplore AI Apps\nor\nBrowse 1M+ models\nTrending on\nthis week\nModels\nQwen/Qwen-Image-Edit\nUpdated\n1 day ago\n•\n608\ngoogle/gemma-3-270m\nUpdated\n6 days ago\n•\n6.49k\n•\n469\ntencent/Hunyuan-GameCraft-1.0\nUpdated\nabout 17 hours ago\n•\n407\ndeepseek-ai/DeepSeek-V3.1-Base\nUpdated\nabout 8 hours ago\n•\n365\nopenai/gpt-oss-20b\nUpdated\n6 days ago\n•\n3.65M\n•\n3.13k\nBrowse 1M+ models\nSpaces\nRunning\n12k\n12k\nDeepSite v2\n🐳\nGenerate any application with DeepSeek\nRunning\non\nZero\n666\n666\nQwen Image\n🖼\nGenerate images from text prompts\nRunning\non\nZero\nMCP\n231\n231\nWan2.2 14B Fast\n🎥\ngenerate a video from an image with a text prompt\nRunning\non\nZero\n132\n132\nOvis2.5 9B\n📊\nHigh-accuracy vision & reasoning for complex tasks\nRunning\non\nZero\n117\n117\nQwen Image Edit\n✒\nEdit images based on user instructions\nBrowse 400k+ applications\nDatasets\nfka/awesome-chatgpt-prompts\nUpdated\nJan 6\n•\n32.1k\n•\n8.76k\nnvidia/Granary\nUpdated\n5 days ago\n•\n726\n•\n83\nnvidia/Llama-Nemotron-VLM-Dataset-v1\nUpdated\nabout 8 hours ago\n•\n1.44k\n•\n94\nallenai/WildChat-4.8M\nUpdated\n8 days ago\n•\n1.37k\n•\n78\nmiromind-ai/MiroVerse-v0.1\nUpdated\n6 days ago\n•\n578\n•\n56\nBrowse 250k+ datasets\nThe Home of Machine Learning\nCreate, discover and collaborate on ML better.\nThe collaboration platform\nHost and collaborate on unlimited public models, datasets and applications.\nMove faster\nWith the HF Open source stack.\nExplore all modalities\nText, image, video, audio or even 3D.\nBuild your portfolio\nShare your work with the world and build your ML profile.\nSign Up\nAccelerate your ML\nWe provide paid Compute and Enterprise solutions.\nCompute\nDeploy on optimized\nInference Endpoints\nor update your\nSpaces applications\nto a GPU in a few clicks.\nView pricing\nStarting at $0.60/hour for GPU\nTeam & Enterprise\nGive your team the most advanced platform to build AI with enterprise-grade security, access controls and\n\t\t\tdedicated support.\nGetting started\nStarting at $20/user/month\nSingle Sign-On\nRegions\nPriority Support\nAudit Logs\nResource Groups\nPrivate Datasets Viewer\nMore than 50,000 organizations are using Hugging Face\nAi2\nEnterprise\nnon-profit\n•\n783 models\n•\n3.87k followers\nAI at Meta\nEnterprise\ncompany\n•\n2.21k models\n•\n7.31k followers\nAmazon\ncompany\n•\n20 models\n•\n3.36k followers\nGoogle\nEnterprise\ncompany\n•\n1.04k models\n•\n25.2k followers\nIntel\ncompany\n•\n242 models\n•\n2.9k followers\nMicrosoft\ncompany\n•\n419 models\n•\n14.2k followers\nGrammarly\nTeam\ncompany\n•\n11 models\n•\n172 followers\nWriter\nEnterprise\ncompany\n•\n21 models\n•\n321 followers\nOur Open Source\nWe are building the foundation of ML tooling with the community.\nTransformers\n148,519\nState-of-the-art AI models for PyTorch\nDiffusers\n30,366\nState-of-the-art Diffusion models in PyTorch\nSafetensors\n3,404\nSafe way to store/distribute neural network weights\nHub Python Library\n2,852\nPython client to interact with the Hugging Face Hub\nTokenizers\n10,001\nFast tokenizers optimized for research & production\nTRL\n15,162\nTrain transformers LMs with reinforcement learning\nTransformers.js\n14,372\nState-of-the-art ML running directly in your browser\nsmolagents\n22,225\nSmol library to build great agents in Python\nPEFT\n19,355\nParameter-efficient finetuning for large language models\nDatasets\n20,525\nAccess & share datasets for any ML tasks\nText Generati ...

# %%
def create_brochure(company_name, url):
    response = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
    )
    result = response.choices[0].message.content
    display(Markdown(result))

# %%
create_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog', 'url': 'https://huggingface.co/blog'}, {'type': 'company page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}]}
# # Hugging Face Brochure
#
# ## About Us
# Welcome to **Hugging Face**, an innovative AI community dedicated to building the future of machine learning. We are a collaborative hub for researchers, developers, and organizations looking to explore AI models, datasets, and applications. Our mission is to democratize artificial intelligence and create an inclusive space for all who are passionate about machine learning.
#
# ---
#
# ## Our Offerings
#
# ### Models
# Explore over **1 million models** across various applications and use cases. Whether it's text, image, video, or audio, our platform allows you to create, discover, and collaborate effectively.
#
# ### Datasets
# Access a vast library of **250,000+ datasets** tailored for machine learning tasks to aid your projects and research.
#
# ### Spaces
# With **12,000 active spaces**, you can run applications seamlessly, collaborate with others, and showcase your work to a wide audience.
#
# ### Compute & Enterprise Solutions
# We provide enterprise-grade solutions with robust security, access controls, and dedicated support starting at **$20/user/month**. Our computing options start as low as **$0.60/hour for GPU** services, enabling your team to harness powerful AI tools efficiently.
#
# ---
#
# ## Our Community
# Hugging Face is home to over **50,000 organizations**, including top names like Google, Microsoft, Amazon, and Meta. We foster a vibrant community where members can share knowledge, contribute to open-source tools, and collaborate on groundbreaking projects.
#
# ### Open Source
# We actively contribute to the open-source ecosystem, offering a range of tools, such as:
# - **Transformers**: Cutting-edge AI models for PyTorch
# - **Diffusers**: Advanced diffusion models
# - **Safetensors**: A secure method for storing neural network weights
# - And many more!
#
# ---
#
# ## Company Culture
# At Hugging Face, we emphasize a **collaborative and inclusive culture**. We believe in open communication, continuous learning, and providing ample opportunities for professional growth. Our team comprises passionate individuals who are committed to shaping the future of AI together.
#
# ---
#
# ## Career Opportunities
# We are always on the lookout for innovative and talented individuals to join our team. If you are interested in being part of a community that values creativity and collaboration, check our careers page for current job openings. By joining us, you can help mold the future of machine learning and make a significant impact.
#
# ---
#
# ## Join Us!
# Whether you are a developer, a researcher, or an organization looking to leverage AI, Hugging Face is the ideal platform for collaboration and innovation. **Sign up today** to start your journey with us!
#
# ---
#
# ### Connect with Us
# - [GitHub](https://github.com/huggingface)
# - [Twitter](https://twitter.com/huggingface)
# - [LinkedIn](https://linkedin.com/company/huggingface)
# - [Discord](https://discord.gg/huggingface)
#
# Together, let’s build the future of AI!

# %% [markdown]
# ## Finally - a minor improvement
#
# With a small adjustment, we can change this so that the results stream back from OpenAI,
# with the familiar typewriter animation

# %%
def stream_brochure(company_name, url):
    stream = openai.chat.completions.create(
        model=MODEL,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": get_brochure_user_prompt(company_name, url)}
          ],
        stream=True
    )
    
    response = ""
    display_handle = display(Markdown(""), display_id=True)
    for chunk in stream:
        response += chunk.choices[0].delta.content or ''
        response = response.replace("```","").replace("markdown", "")
        update_display(Markdown(response), display_id=display_handle.display_id)

# %%
stream_brochure("HuggingFace", "https://huggingface.co")
# Out:
# Found links: {'links': [{'type': 'about page', 'url': 'https://huggingface.co/huggingface'}, {'type': 'careers page', 'url': 'https://apply.workable.com/huggingface/'}, {'type': 'blog page', 'url': 'https://huggingface.co/blog'}, {'type': 'enterprise page', 'url': 'https://huggingface.co/enterprise'}, {'type': 'pricing page', 'url': 'https://huggingface.co/pricing'}, {'type': 'models page', 'url': 'https://huggingface.co/models'}, {'type': 'datasets page', 'url': 'https://huggingface.co/datasets'}, {'type': 'spaces page', 'url': 'https://huggingface.co/spaces'}, {'type': 'discuss page', 'url': 'https://discuss.huggingface.co'}, {'type': 'GitHub page', 'url': 'https://github.com/huggingface'}, {'type': 'LinkedIn page', 'url': 'https://www.linkedin.com/company/huggingface/'}, {'type': 'Twitter page', 'url': 'https://twitter.com/huggingface'}]}
# # Hugging Face Brochure
#
# ## About Us
# **Hugging Face** is a leading platform in the AI community, dedicated to building the future of artificial intelligence and machine learning. Our mission is to democratize AI technology and foster collaboration among developers, researchers, and businesses, empowering everyone to create, discover, and share innovative AI solutions.
#
# ---
#
# ## Our Offerings
# ### **Models & Datasets**
# - **Models**: Access and explore over 1 million AI models, including cutting-edge implementations for text, image, video, audio, and even 3D applications.
# - **Datasets**: Collaborate on and utilize a vast repository of over 250,000 datasets, tailored for various machine learning tasks.
#
# ### **Spaces**
# - Host and showcase your AI applications effortlessly with our user-friendly platform, which supports the creation and running of thousands of applications.
#
# ### **Enterprise Solutions**
# - **Compute**: Accelerate your projects with paid compute options starting at $0.60/hour for GPU usage.
# - **Team & Enterprise Packages**: Ideal for organizations, these plans offer enhanced security, support, and tools for large-scale AI development starting at $20/user/month.
#
# ---
#
# ## Community Engagement
# At Hugging Face, we believe in the power of community collaboration. Our platform allows users to:
# - Share their work and showcase their projects, building a global community of 54,752 followers who share an interest in AI and ML.
# - Collaborate and learn from peers, developing better models and solutions together.
#
# ---
#
# ## Company Culture
# Hugging Face fosters an inclusive and dynamic work environment where innovation thrives. Our culture is characterized by:
# - **Collaboration**: We emphasize teamwork and knowledge-sharing to accelerate learning and development.
# - **Open Source Focus**: We are committed to building the foundational tools for machine learning in an open and transparent manner, enabling everyone to contribute and benefit.
# - **Empowerment**: We empower our team members to take initiative, innovate, and push the boundaries of what's possible in AI.
#
# ---
#
# ## Career Opportunities
# Join our team at Hugging Face and be a part of shaping the future of AI! We are looking for passionate individuals who are eager to contribute to the AI community. Career opportunities span various fields including engineering, data science, product management, and more. To discover our current openings, please visit our [careers page](https://huggingface.co/jobs).
#
# ---
#
# ## Our Customers
# More than 50,000 organizations, including industry giants like Google, Microsoft, Amazon, and others, trust Hugging Face as their partner in AI development, leveraging our community-driven models and solutions for their projects.
#
# ---
#
# ## Get Involved
# Explore our website and become a part of the Hugging Face community today! Dive into our resources [here](https://huggingface.co).
#
# ---
#
# Together, let’s build the future of AI!

# %%
# Try changing the system prompt to the humorous version when you make the Brochure for Hugging Face:

stream_brochure("HuggingFace", "https://huggingface.co")

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business applications</h2>
#             <span style="color:#181;">In this exercise we extended the Day 1 code to make multiple LLM calls, and generate a document.
#
# This is perhaps the first example of Agentic AI design patterns, as we combined multiple calls to LLMs. This will feature more in Week 2, and then we will return to Agentic AI in a big way in Week 8 when we build a fully autonomous Agent solution.
#
# Generating content in this way is one of the very most common Use Cases. As with summarization, this can be applied to any business vertical. Write marketing content, generate a product tutorial from a spec, create personalized email content, and so much more. Explore how you can apply content generation to your business, and try making yourself a proof-of-concept prototype. See what other students have done in the community-contributions folder -- so many valuable projects -- it's wild!</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you move to Week 2 (which is tons of fun)</h2>
#             <span style="color:#900;">Please see the week1 EXERCISE notebook for your challenge for the end of week 1. This will give you some essential practice working with Frontier APIs, and prepare you well for Week 2.</span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">A reminder on 3 useful resources</h2>
#             <span style="color:#f71;">1. The resources for the course are available <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">here.</a><br/>
#             2. I'm on LinkedIn <a href="https://www.linkedin.com/in/eddonner/">here</a> and I love connecting with people taking the course!<br/>
#             3. I'm trying out X/Twitter and I'm at <a href="https://x.com/edwarddonner">@edwarddonner<a> and hoping people will teach me how it's done..
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">Finally! I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a MASSIVE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
